# %% [markdown]
# <img src="Archivos/miia.jpg" width=800x>
#
# # Laboratorio 1
#
# ## Desarrollo de una herramienta analítica usando solo Python
#
# Este laboratorio busca evaluar las habilidades relacionadas con la primera parte del curso, correspondiente a las primeras tres semanas. Este enunciado estará disponible desde la semana 2 y deberá entregarse al final de la semana 4 en el enlace correspondiente. Su desarrollo corresponde al 30% de la calificación total del curso.
#
# Esta actividad responde directamente al segundo objetivo del curso:
# * Implementar una herramienta analítica que permita responder una pregunta de negocio para un problema sencillo de analítica de datos, utilizando únicamente algorítmica básica en Python.
#
# Al desarrollar este laboratorio pondrás a prueba tus habilidades para:
# 1. Leer datos desde archivos.
# 2. Almacenar datos en  estructuras de Python.
# 3. Crear y llamar funciones correctamente.
# 4. Implementar condicionales diferenciando *if*, *elif* y *else*
# 5. Implementar ciclos diferenciando el propósito de *for* y *while*
# 6. Importar paquetes y utilizar sus funciones.
#
# **NOTAS:**
# - Te recomendamos leer por completo el enunciado del laboratorio antes de comenzar, de forma que tengas claro el propósito completo de la actividad, y puedas desarrollar tu solución apuntando a él desde el comienzo.

# %% [markdown]
# ## Contexto: exploración del potencial para asignar becas Uniandes
# La Universidad de los Andes se ha caracterizado por su compromiso con la generación de impacto en la sociedad a través de diferentes programas de becas. Programas como Quiero Estudiar, o Ser Pilo Paga, entre otros, han sido revolucionarios, al permitir que estudiantes de bajos recursos puedan acceder a una de las universidades privadas más importantes del país.
#
# Actualmente, la Universidad quiere evaluar el potencial impacto que tendrían algunos programas de *acción afirmativa* para asignación de becas, con base en información demográfica que ha obtenido a través de encuestas. Se cuenta con información respecto a la edad, género, estado civil, estrato socio-económico, región de proveniencia, desempeño académico y nivel de escolaridad de las personas que han respondido encuestas. Los encargados de diseñar el programa saben que utilizar criterios basados en este tipo de variables es un tema sensible, pero es necesario si se quieren focalizar las oportunidades en poblaciones menos representadas.
#
# El objetivo de este laboratorio es crear una herramienta computacional que permita a un tomador de decisiones explorar qué efecto podría tener el uso de diferentes reglas para seleccionar la población que sería beneficiaria de las becas. Puntualmente, se espera que, dadas unas reglas de selección (ej.: pertenecer a cierta región, rango de edad, etc.), la herramienta ofrezca información sobre la población potencialmente beneficiada, de forma que exista un sustento al momento de definir las reglas de selección.

# %% [markdown]
# ## 1. Obtención e inspección de archivos
#
# Los datos de encuestas fueron obtenidos como parte de un trabajo de campo, y por limitaciones tecnológicas, solo se cuenta con la información en archivos de texto plano. Cada archivo corresponde a una de las variables antes mencionadas y se puede garantizar que todos relacionan a las personas encuestadas en el mismo orden (i.e., la primera línea de todos los archivos corresponde a datos de la primera persona encuestada, la segunda línea a la segunda persona, etc.).
#
# Los archivos con los que se cuenta son:
# * *edades.txt*: un archivo ordenado con las edades de cada persona de la población encuestada
# * *género.txt*: un archivo ordenado con el género de cada persona de la población encuestada
# * *estado_civil.txt*: un archivo ordenado con el estado civil de cada persona de la población encuestada
# * *escolaridad.txt*: un archivo ordenado con el nivel de escolaridad de cada persona de la población encuestada
# * *estrato.txt*: un archivo ordenado con el estrato socio-económico de cada persona de la población encuestada
# * *region.txt*: un archivo ordenado con la región de proveniencia de cada persona de la población encuestada

# %% [markdown]
# **Misión 1**
#
# Poner en variables de Python la información que está en los archivos listados arriba.
#
# * *Versión base*: escribe línea a línea el código necesario para poner en variables de Python la información de cada uno de los archivos.
#
# * *Milla extra*: escribe una función que sea capaz de hacer lo anterior para un archivo y úsala en un ciclo para automatizar la lectura de los diferentes archivos.

# %%
#edades =  open("edad.txt")
#escolaridad = open("escolaridad.txt")
#estado_civil = open("estado_civil.txt")
estrato = open("estrato.txt")
#genero = open("genero.txt")
#promedio = open("promedio.txt")
#region =open("region.txt")

with open("edad.txt", "r") as archivo:
    edades = [int(linea) for linea in archivo]

with open("escolaridad.txt", "r") as archivo:
    escolaridad = [linea.rstrip() for linea in archivo]

with open("estado_civil.txt", "r") as archivo:
    estado_civil = [linea.rstrip() for linea in archivo]
    
with open("genero.txt", "r") as archivo:
    genero = [linea.rstrip() for linea in archivo]
    
with open("promedio.txt", "r") as archivo:
    promedio = [float(linea) for linea in archivo]

with open("region.txt", "r") as archivo:
    region = [linea.rstrip() for linea in archivo]
    
with open("estrato.txt", "r") as archivo:
    estrato = [int(linea) for linea in archivo]

# %% [markdown]
# **Misión 2**
#
# Reportar las principales características en los datos.
# * *Versión base*: utilizar métricas básicas como conteos o promedios por categorías en los datos.
# * *Milla extra*: utilizar visualizaciones simples como diagramas de barras, de pastel u otros.

# %%
# código

# importación de paquetes necesarios
import statistics
import numpy as np
# función que calcula la mediana de una lista de datos numéricos

def obtener_mediana(arreglo):
    x = sorted(arreglo)
    longitud = len(x)
    mitad = int(longitud / 2)
    if longitud % 2 == 0:
        mediana = (x[mitad - 1]+x[mitad]) / 2
    else:
        mediana = x[mitad]
    return mediana

m_edades = obtener_mediana(edades)
print ("mediana de edades",m_edades)

m_promedio = obtener_mediana(promedio)
print ("mediana de promedio", m_promedio)

m_estrato = obtener_mediana(estrato)
print ("mediana de estrato", m_estrato)

print(statistics.median(edades))
#print(statistics.median(escolaridad))
#print(statistics.median(estado_civil))
#print(statistics.median(estrato))
#print(statistics.median(genero))
print(statistics.median(promedio))
#print(statistics.median(region))



# función que calcula la desviación de una lista de datos numéricos

des_edades = np.std(edades)
print ("desviación estándar de edades", des_edades)

des_promedio = np.std(promedio)
print ("desviación estándar de promedio", des_promedio)

des_estrato = np.std(estrato)
print ("desviación estándar de promedio", des_estrato)

import numpy as np
import matplotlib.pyplot as plt
 

 
numero_de_grupos = len(promedio)
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.35
 
plt.bar(indice_barras, promedio, width=ancho_barras, label='Promedio')
#plt.bar(indice_barras + ancho_barras, serie_2, width=ancho_barras, label='Mujeres')
plt.legend(loc='best')
## Se colocan los indicadores en el eje x
#plt.xticks(indice_barras + ancho_barras, ('2017', '2018', '2019', '2020','2021'))
 
plt.ylabel('Numero de promedio')
plt.xlabel('Cantidad de personas')
plt.title('Numero de personas por promedio')
 
plt.show()
#------------------------------------------------------------------------------------- 

numero_de_grupos = len(edades)
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.35
 
plt.bar(indice_barras, edades, width=ancho_barras, label='Edades')
#plt.bar(indice_barras + ancho_barras, serie_2, width=ancho_barras, label='Mujeres')
plt.legend(loc='best')
## Se colocan los indicadores en el eje x
#plt.xticks(indice_barras + ancho_barras, ('2017', '2018', '2019', '2020','2021'))
 
plt.ylabel('Edad')
plt.xlabel('Cantidad de personas')
plt.title('Numero de personas por edad')

plt.show()
#------------------------------------------------------------------------------------- 
numero_de_grupos = len(estrato)
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.35
 
plt.bar(indice_barras, estrato, width=ancho_barras, label='estrato')
#plt.bar(indice_barras + ancho_barras, serie_2, width=ancho_barras, label='Mujeres')
plt.legend(loc='best')
## Se colocan los indicadores en el eje x
#plt.xticks(indice_barras + ancho_barras, ('2017', '2018', '2019', '2020','2021'))
 
plt.ylabel('estrato')
plt.xlabel('Cantidad de personas')
plt.title('Numero de personas por estrato')
 
plt.show()
# Out:
# mediana de edades 49.0
# mediana de promedio 2.7
# mediana de estrato 2.0
# 49.0
# 2.7
# desviación estándar de edades 18.59485133040864
# desviación estándar de promedio 1.1159169144698902
# desviación estándar de promedio 0.9762868430947945

# %% [markdown]
# ## 2. Abordaje de la pregunta de negocio
#
# El comité encargado de diseñar el programa de becas ha tenido dificultades para llegar a acuerdos. Algunos piensan que el criterio principal de selección debería ser respecto a lo económico y académico, sin importar otras características personales, mientras que otros piensan que considerar estas características es, de hecho, parte del espíritu del programa.
#
# * El primer grupo sugiere que se deben tomar en orden ascendente los estratos y elegir, en cada uno de ellos, al 2% de personas con promedio académico superior en esa sub-población, hasta que se agoten las becas disponibles. En caso de quedar becas disponibles al final del proceso, se repite el mismo esquema, considerando que ya no se tienen en cuenta las personas que hayan sido elegidas en rondas anteriores.
#
# * El segundo grupo sugiere que los recibidores de becas deben estar igualmente distribuidos entre las diferentes regiones y generos, considerando, por supuesto, que para cada una de esas sub-poblaciones, las personas elegidas sean las de mejores promedios académicos.
#
# Dado que las diferencias entre estos grupos obedecen a su entendimiento particular del problema, el presidente del comité propone utilizar los datos disponibles de las encuestas, sugiriendo que se analice qué características tendría la población de elegidos bajo cada uno de los dos criterios expuestos.

# %% [markdown]
# **Misión 3**
#
# Defina la pregunta de negocio y la pregunta de *analytics* para esta situación.

# %%
# respuesta en texto (solo leeremos los primeros 300 caracteres de la respuesta)

pregunta_negocio = '¿Cual es el mejor sistema para la asignación de becas focalizando las oportunidades en poblaciones menos representadas? '

pregunta_analytics = '¿Cual es la mejor forma de implementar los diferentes escenarios, cumpliendo los diferentes requerimientos?'

# %% [markdown]
# **Misión 4**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *primer grupo* mencionado arriba.

# %%
import math

#enumerar la lista

list(enumerate (edades))
list(enumerate (escolaridad))
list(enumerate (estado_civil))
list(enumerate (estrato))
list(enumerate (genero))
list(enumerate (promedio))
list(enumerate (region))
llave = range(0,500)

#conocer el grupo de elementos de la lista estrato

from collections import OrderedDict  
  
def group_list(x): 
    res =  [(el, x.count(el)) for el in x ] 
    return list(OrderedDict(res).items()) 

print(group_list(estrato))


e5_edades=[]
e5_escolaridad=[]
e5_estado_civil=[]
e5_estrato=[]
e5_genero=[]
e5_promedio=[]
e5_region=[]
e5_llave =[]

e4_edades=[]
e4_escolaridad=[]
e4_estado_civil=[]
e4_estrato=[]
e4_genero=[]
e4_promedio=[]
e4_region=[]
e4_llave =[]

e3_edades=[]
e3_escolaridad=[]
e3_estado_civil=[]
e3_estrato=[]
e3_genero=[]
e3_promedio=[]
e3_region=[]
e3_llave =[]

e2_edades=[]
e2_escolaridad=[]
e2_estado_civil=[]
e2_estrato=[]
e2_genero=[]
e2_promedio=[]
e2_region=[]
e2_llave =[]

e1_edades=[]
e1_escolaridad=[]
e1_estado_civil=[]
e1_estrato=[]
e1_genero=[]
e1_promedio=[]
e1_region=[]
e1_llave =[]

#Separa a las personas por estratos
for i in range(len(estrato)):
    if estrato[i] == 5:
        e5_edades.append(edades[i])
        e5_escolaridad.append(escolaridad[i])
        e5_estado_civil.append(estado_civil[i])
        e5_estrato.append(estrato[i])
        e5_genero.append(genero[i])
        e5_promedio.append(promedio[i])
        e5_region.append(region[i])
        e5_llave.append(llave[i])
        
for i in range(len(estrato)):
    if estrato[i] == 4:
        e4_edades.append(edades[i])
        e4_escolaridad.append(escolaridad[i])
        e4_estado_civil.append(estado_civil[i])
        e4_estrato.append(estrato[i])
        e4_genero.append(genero[i])
        e4_promedio.append(promedio[i])
        e4_region.append(region[i])
        e4_llave.append(llave[i])

for i in range(len(estrato)):
    if estrato[i] == 3:
        e3_edades.append(edades[i])
        e3_escolaridad.append(escolaridad[i])
        e3_estado_civil.append(estado_civil[i])
        e3_estrato.append(estrato[i])
        e3_genero.append(genero[i])
        e3_promedio.append(promedio[i])
        e3_region.append(region[i])
        e3_llave.append(llave[i])   
        
        
for i in range(len(estrato)):
    if estrato[i] == 2:
        e2_edades.append(edades[i])
        e2_escolaridad.append(escolaridad[i])
        e2_estado_civil.append(estado_civil[i])
        e2_estrato.append(estrato[i])
        e2_genero.append(genero[i])
        e2_promedio.append(promedio[i])
        e2_region.append(region[i])   
        e2_llave.append(llave[i])
        
for i in range(len(estrato)):
    if estrato[i] == 1:
        e1_edades.append(edades[i])
        e1_escolaridad.append(escolaridad[i])
        e1_estado_civil.append(estado_civil[i])
        e1_estrato.append(estrato[i])
        e1_genero.append(genero[i])
        e1_promedio.append(promedio[i])
        e1_region.append(region[i])   
        e1_llave.append(llave[i])

#unir todos los datos en una lista y ordenarlos por el promedio

e5 = list(zip(e5_llave,e5_edades,e5_escolaridad,e5_estado_civil,e5_estrato,e5_genero,e5_promedio,e5_region))
e5.sort(key = lambda x: x[6], reverse = True)

e4 = list(zip(e4_llave,e4_edades,e4_escolaridad,e4_estado_civil,e4_estrato,e4_genero,e4_promedio,e4_region))
e4.sort(key = lambda x: x[6], reverse = True)

e3 = list(zip(e3_llave,e3_edades,e3_escolaridad,e3_estado_civil,e3_estrato,e3_genero,e3_promedio,e3_region))
e3.sort(key = lambda x: x[6], reverse = True)

e2 = list(zip(e2_llave,e2_edades,e2_escolaridad,e2_estado_civil,e2_estrato,e2_genero,e2_promedio,e2_region))
e2.sort(key = lambda x: x[6], reverse = True)

e1 = list(zip(e1_llave,e1_edades,e1_escolaridad,e1_estado_civil,e1_estrato,e1_genero,e1_promedio,e1_region))
e1.sort(key = lambda x: x[6], reverse = True)


for i in e5:
    print (i)
# Out:
# [(5, 13), (1, 111), (3, 156), (2, 185), (4, 35)]
# (259, 60, 'Secundaria', 'soltera', 5, 'no binario', 4.8, 'Andina')
# (99, 64, 'Secundaria', 'viuda', 5, 'femenino', 3.4, 'Orinoquia')
# (38, 47, 'Secundaria', 'casada', 5, 'femenino', 3.3, 'Caribe')
# (242, 50, 'Profesional', 'casada', 5, 'femenino', 3.3, 'Caribe')
# (351, 18, 'Secundaria', 'divorciada', 5, 'masculino', 2.9, 'Caribe')
# (0, 36, 'Secundaria', 'casada', 5, 'masculino', 2.4, 'Andina')
# (196, 54, 'Profesional', 'soltera', 5, 'masculino', 2.4, 'Caribe')
# (296, 56, 'Secundaria', 'casada', 5, 'femenino', 2.4, 'Caribe')
# (360, 23, 'Profesional', 'soltera', 5, 'femenino', 2.2, 'Pacifica')
# (495, 23, 'Secundaria', 'casada', 5, 'femenino', 2.1, 'Caribe')
# (461, 20, 'Profesional', 'casada', 5, 'femenino', 2.0, 'Caribe')
# (354, 77, 'Secundaria', 'soltera', 5, 'masculino', 1.6, 'Caribe')
# (431, 79, 'Secundaria', 'casada', 5, 'masculino', 1.0, 'Andina')

# %%
#elegidos.append(e5(math.ceil(len(e5)*0.02))

print("Ingrese el número de becas que desea asignar en número")
becas = input ()
becas= int (becas)
porcentaje = 0.02

p_e1 =[]
p_e2=[]
p_e3=[]
p_e3=[]
p_e4=[]
p_e5=[]
xe5 = []
xe4 = []
xe3 = []
xe2 = []
xe1 = []
elegidos = []
inicial_e1 = len(e1)
inicial_e2 = len(e2)
inicial_e3 = len(e3)
inicial_e4 = len(e4)
inicial_e5 = len(e5)


#Descuenta las becas
if (inicial_e1+inicial_e2+inicial_e3+inicial_e4+inicial_e5) >= becas:  #evita el error de un ciclo infinito por falta de personas
    if (becas) != 0:      #Garantiza que se asigne un número de becas

        while becas>0:    #Repite el ciclo hasta a signar todas las becas
            if math.ceil(len(e1)*porcentaje) < becas :
                #print(becas,len(elegidos))
                #print(math.ceil(len(e1)*0.02))
                x = math.ceil(len(e1)*porcentaje) #recoge la cantidad de becas asignadas, cantidad a eliminar del número de becas
                p_e1 = e1[0:(math.ceil(len(e1)*porcentaje))]  #guarda el 20% de la lista del estrato 1 en la lista p_e1
                del(e1[0:(math.ceil(len(e1)*porcentaje))])  # borra el 20% de la lista del estrato 1
                becas= becas- x        # elimina del número de becas la cantidad previamente asignada a este estrato
                elegidos.extend(p_e1)   #Recoge las personas elegidas en cada estrato 
                #print(becas,len(elegidos))
                #print(math.ceil(len(e2)*0.02))

                if math.ceil(len(e2)*porcentaje) < becas :
                    x = math.ceil(len(e2)*porcentaje)
                    p_e2 = e2[0:(math.ceil(len(e2)*porcentaje))] 
                    del(e2[0:(math.ceil(len(e2)*porcentaje))])
                    becas= becas- x
                    elegidos.extend(p_e2)
                    #print(becas,len(elegidos))
                    #print(math.ceil(len(e3)*0.02))

                    if math.ceil(len(e3)*porcentaje) < becas :
                        x = math.ceil(len(e3)*porcentaje)
                        p_e3 = e3[0:(math.ceil(len(e3)*porcentaje))]
                        del(e3[0:(math.ceil(len(e3)*porcentaje))])
                        becas= becas - x
                        elegidos.extend(p_e3)
                     #   print(becas,len(elegidos))
                     #   print(math.ceil(len(e4)*0.02))

                        if math.ceil(len(e4)*porcentaje) < becas :
                            x = math.ceil(len(e4)*porcentaje)
                            p_e4 = e4[0:(math.ceil(len(e4)*porcentaje))]  
                            del(e4[0:(math.ceil(len(e4)*porcentaje))])
      
                            becas= becas- x
                            elegidos.extend(p_e4)
                      #      print(becas,len(elegidos))
                       #     print(math.ceil(len(e5)*0.02))

                            if math.ceil(len(e5)*porcentaje) < becas :
                                x = math.ceil(len(e5)*porcentaje)
                                p_e5 = e5[0:(math.ceil(len(e5)*porcentaje))]  
                                del(e5[0:(math.ceil(len(e5)*porcentaje))])
                                becas= becas- x
                                elegidos.extend(p_e5)
                        #        print(becas,len(elegidos))
                            else:
                                xe5 = e5[0:becas] # en caso de que las becas no alcancen el 20% de las personas del estrato, se asignan sólo las disponibles 
                                del (e5[0:becas])
                                becas = 0 #el núemro de becas se vuelve 0 y se asignan sol
                                elegidos.extend(xe5)
                        else: 
                            xe4 = e4[0:becas]
                            del (e4[0:becas])
                            becas = 0
                            elegidos.extend(xe4)
                    else: 
                        xe3 = e3[0:becas]
                        del (e3[0:becas])
                        becas = 0
                        elegidos.extend(xe3)
                else: 
                    xe2 = e2[0:becas]
                    del (e2[0:becas])
                    becas = 0
                    elegidos.extend(xe2)
            else: 
                xe1 = e1[0:becas]
                del (e1[0:becas])
                becas = 0
                elegidos.extend(xe1)



        print("Se le asignaron", inicial_e5-len(e5) , "becas al estrato 5, quedan ",len(e5), "personas")
        print("Se le asignaron", inicial_e4-len(e4) , "becas al estrato 4, quedan ",len(e4), "personas")
        print("Se le asignaron", inicial_e3-len(e3) , "becas al estrato 3, quedan ",len(e3), "personas")
        print("Se le asignaron", inicial_e2-len(e2) , "becas al estrato 2, quedan ",len(e2), "personas")
        print("Se le asignaron", inicial_e1-len(e1) , "becas al estrato 1, quedan ",len(e1), "personas")


        print(becas,len(elegidos),"\n")



        i = 0
        for entero in elegidos:
            print(i,entero,"\n")  # imprime la lista de elegidos
            i = i + 1
            
    else:
        print("no hay una cantidad de becas disponibles para asignar")
else:
    print ("Enhorabuena se le han asignado becas a todas las personas y quedaron", becas - (inicial_e1+inicial_e2+inicial_e3+inicial_e4+inicial_e5), "por asignar")
# Out:
# Ingrese el número de becas que desea asignar en número
# 100
# Se le asignaron 8 becas al estrato 5, quedan  5 personas
# Se le asignaron 8 becas al estrato 4, quedan  27 personas
# Se le asignaron 26 becas al estrato 3, quedan  130 personas
# Se le asignaron 36 becas al estrato 2, quedan  149 personas
# Se le asignaron 22 becas al estrato 1, quedan  89 personas
# 0 100
#
# 0 (376, 69, 'Secundaria', 'soltera', 1, 'masculino', 5.0, 'Pacifica')
#
# 1 (162, 47, 'Secundaria', 'casada', 1, 'masculino', 4.9, 'Andina')
#
# 2 (363, 32, 'Secundaria', 'casada', 1, 'femenino', 4.9, 'Pacifica')
#
# 3 (243, 59, 'Secundaria', 'divorciada', 2, 'femenino', 5.0, 'Caribe')
#
# 4 (7, 54, 'Secundaria', 'casada', 2, 'femenino', 4.9, 'Andina')
#
# 5 (207, 21, 'Profesional', 'casada', 2, 'femenino', 4.9, 'Andina')
#
# 6 (491, 59, 'Profesional', 'casada', 2, 'masculino', 4.9, 'Caribe')
#
# 7 (60, 75, 'Primaria', 'casada', 3, 'femenino', 4.9, 'Caribe')
#
# ...

# %% [markdown]
# **Misión 5**
#
# Desarrollar un algoritmo que permita conocer la población que sería becada según los criterios propuestos por el *segundo grupo* mencionado arriba.

# %%
#enumerar la lista

list(enumerate (edades))
list(enumerate (escolaridad))
list(enumerate (estado_civil))
list(enumerate (estrato))
list(enumerate (genero))
list(enumerate (promedio))
list(enumerate (region))
llave = range(0,500)

#conocer el grupo de elementos de la lista regiones

from collections import OrderedDict  
  
def group_list(x): 
    res =  [(el, x.count(el)) for el in x ] 
    return list(OrderedDict(res).items()) 

print(group_list(region))

#conocer el grupo de elementos de la lista generos

def group_list(x): 
    res =  [(el, x.count(el)) for el in x ] 
    return list(OrderedDict(res).items()) 

print(group_list(genero))


m_Andina_edades=[]
m_Andina_escolaridad=[]
m_Andina_estado_civil=[]
m_Andina_estrato=[]
m_Andina_genero=[]
m_Andina_promedio=[]
m_Andina_region=[]
m_Andina_llave =[]

f_Andina_edades=[]
f_Andina_escolaridad=[]
f_Andina_estado_civil=[]
f_Andina_estrato=[]
f_Andina_genero=[]
f_Andina_promedio=[]
f_Andina_region=[]
f_Andina_llave =[]

o_Andina_edades=[]
o_Andina_escolaridad=[]
o_Andina_estado_civil=[]
o_Andina_estrato=[]
o_Andina_genero=[]
o_Andina_promedio=[]
o_Andina_region=[]
o_Andina_llave =[]

n_Andina_edades=[]
n_Andina_escolaridad=[]
n_Andina_estado_civil=[]
n_Andina_estrato=[]
n_Andina_genero=[]
n_Andina_promedio=[]
n_Andina_region=[]
n_Andina_llave =[]

m_Pacifica_edades=[]
m_Pacifica_escolaridad=[]
m_Pacifica_estado_civil=[]
m_Pacifica_estrato=[]
m_Pacifica_genero=[]
m_Pacifica_promedio=[]
m_Pacifica_region=[]
m_Pacifica_llave =[]

f_Pacifica_edades=[]
f_Pacifica_escolaridad=[]
f_Pacifica_estado_civil=[]
f_Pacifica_estrato=[]
f_Pacifica_genero=[]
f_Pacifica_promedio=[]
f_Pacifica_region=[]
f_Pacifica_llave =[]

o_Pacifica_edades=[]
o_Pacifica_escolaridad=[]
o_Pacifica_estado_civil=[]
o_Pacifica_estrato=[]
o_Pacifica_genero=[]
o_Pacifica_promedio=[]
o_Pacifica_region=[]
o_Pacifica_llave =[]

n_Pacifica_edades=[]
n_Pacifica_escolaridad=[]
n_Pacifica_estado_civil=[]
n_Pacifica_estrato=[]
n_Pacifica_genero=[]
n_Pacifica_promedio=[]
n_Pacifica_region=[]
n_Pacifica_llave =[]

m_Orinoquia_edades=[]
m_Orinoquia_escolaridad=[]
m_Orinoquia_estado_civil=[]
m_Orinoquia_estrato=[]
m_Orinoquia_genero=[]
m_Orinoquia_promedio=[]
m_Orinoquia_region=[]
m_Orinoquia_llave =[]

f_Orinoquia_edades=[]
f_Orinoquia_escolaridad=[]
f_Orinoquia_estado_civil=[]
f_Orinoquia_estrato=[]
f_Orinoquia_genero=[]
f_Orinoquia_promedio=[]
f_Orinoquia_region=[]
f_Orinoquia_llave =[]

o_Orinoquia_edades=[]
o_Orinoquia_escolaridad=[]
o_Orinoquia_estado_civil=[]
o_Orinoquia_estrato=[]
o_Orinoquia_genero=[]
o_Orinoquia_promedio=[]
o_Orinoquia_region=[]
o_Orinoquia_llave =[]

n_Orinoquia_edades=[]
n_Orinoquia_escolaridad=[]
n_Orinoquia_estado_civil=[]
n_Orinoquia_estrato=[]
n_Orinoquia_genero=[]
n_Orinoquia_promedio=[]
n_Orinoquia_region=[]
n_Orinoquia_llave =[]

m_Caribe_edades=[]
m_Caribe_escolaridad=[]
m_Caribe_estado_civil=[]
m_Caribe_estrato=[]
m_Caribe_genero=[]
m_Caribe_promedio=[]
m_Caribe_region=[]
m_Caribe_llave =[]

f_Caribe_edades=[]
f_Caribe_escolaridad=[]
f_Caribe_estado_civil=[]
f_Caribe_estrato=[]
f_Caribe_genero=[]
f_Caribe_promedio=[]
f_Caribe_region=[]
f_Caribe_llave =[]

o_Caribe_edades=[]
o_Caribe_escolaridad=[]
o_Caribe_estado_civil=[]
o_Caribe_estrato=[]
o_Caribe_genero=[]
o_Caribe_promedio=[]
o_Caribe_region=[]
o_Caribe_llave =[]

n_Caribe_edades=[]
n_Caribe_escolaridad=[]
n_Caribe_estado_civil=[]
n_Caribe_estrato=[]
n_Caribe_genero=[]
n_Caribe_promedio=[]
n_Caribe_region=[]
n_Caribe_llave =[]

m_Amazonia_edades=[]
m_Amazonia_escolaridad=[]
m_Amazonia_estado_civil=[]
m_Amazonia_estrato=[]
m_Amazonia_genero=[]
m_Amazonia_promedio=[]
m_Amazonia_region=[]
m_Amazonia_llave =[]

f_Amazonia_edades=[]
f_Amazonia_escolaridad=[]
f_Amazonia_estado_civil=[]
f_Amazonia_estrato=[]
f_Amazonia_genero=[]
f_Amazonia_promedio=[]
f_Amazonia_region=[]
f_Amazonia_llave =[]

o_Amazonia_edades=[]
o_Amazonia_escolaridad=[]
o_Amazonia_estado_civil=[]
o_Amazonia_estrato=[]
o_Amazonia_genero=[]
o_Amazonia_promedio=[]
o_Amazonia_region=[]
o_Amazonia_llave =[]

n_Amazonia_edades=[]
n_Amazonia_escolaridad=[]
n_Amazonia_estado_civil=[]
n_Amazonia_estrato=[]
n_Amazonia_genero=[]
n_Amazonia_promedio=[]
n_Amazonia_region=[]
n_Amazonia_llave =[]


#Separa a las personas por estratos
for i in range(len(region)):
    if region[i] == "Andina" and genero[i] == "masculino":
        m_Andina_edades.append(edades[i])
        m_Andina_escolaridad.append(escolaridad[i])
        m_Andina_estado_civil.append(estado_civil[i])
        m_Andina_estrato.append(estrato[i])
        m_Andina_genero.append(genero[i])
        m_Andina_promedio.append(promedio[i])
        m_Andina_region.append(region[i])   
        m_Andina_llave.append(llave[i])
    elif region[i] == "Andina" and genero[i] == "femenino":
        f_Andina_edades.append(edades[i])
        f_Andina_escolaridad.append(escolaridad[i])
        f_Andina_estado_civil.append(estado_civil[i])
        f_Andina_estrato.append(estrato[i])
        f_Andina_genero.append(genero[i])
        f_Andina_promedio.append(promedio[i])
        f_Andina_region.append(region[i])   
        f_Andina_llave.append(llave[i])
    elif region[i] == "Andina" and genero[i] == "otro":
        o_Andina_edades.append(edades[i])
        o_Andina_escolaridad.append(escolaridad[i])
        o_Andina_estado_civil.append(estado_civil[i])
        o_Andina_estrato.append(estrato[i])
        o_Andina_genero.append(genero[i])
        o_Andina_promedio.append(promedio[i])
        o_Andina_region.append(region[i])   
        o_Andina_llave.append(llave[i])
    elif region[i] == "Andina" and genero[i] == "no binario":
        n_Andina_edades.append(edades[i])
        n_Andina_escolaridad.append(escolaridad[i])
        n_Andina_estado_civil.append(estado_civil[i])
        n_Andina_estrato.append(estrato[i])
        n_Andina_genero.append(genero[i])
        n_Andina_promedio.append(promedio[i])
        n_Andina_region.append(region[i])   
        n_Andina_llave.append(llave[i])
        
for i in range(len(region)):
    if region[i] == "Pacifica" and genero[i] == "masculino":
        m_Pacifica_edades.append(edades[i])
        m_Pacifica_escolaridad.append(escolaridad[i])
        m_Pacifica_estado_civil.append(estado_civil[i])
        m_Pacifica_estrato.append(estrato[i])
        m_Pacifica_genero.append(genero[i])
        m_Pacifica_promedio.append(promedio[i])
        m_Pacifica_region.append(region[i])   
        m_Pacifica_llave.append(llave[i])
    elif region[i] == "Pacifica" and genero[i] == "femenino":
        f_Pacifica_edades.append(edades[i])
        f_Pacifica_escolaridad.append(escolaridad[i])
        f_Pacifica_estado_civil.append(estado_civil[i])
        f_Pacifica_estrato.append(estrato[i])
        f_Pacifica_genero.append(genero[i])
        f_Pacifica_promedio.append(promedio[i])
        f_Pacifica_region.append(region[i])   
        f_Pacifica_llave.append(llave[i])
    elif region[i] == "Pacifica" and genero[i] == "otro":
        o_Pacifica_edades.append(edades[i])
        o_Pacifica_escolaridad.append(escolaridad[i])
        o_Pacifica_estado_civil.append(estado_civil[i])
        o_Pacifica_estrato.append(estrato[i])
        o_Pacifica_genero.append(genero[i])
        o_Pacifica_promedio.append(promedio[i])
        o_Pacifica_region.append(region[i])   
        o_Pacifica_llave.append(llave[i])
    elif region[i] == "Pacifica" and genero[i] == "no binario":
        n_Pacifica_edades.append(edades[i])
        n_Pacifica_escolaridad.append(escolaridad[i])
        n_Pacifica_estado_civil.append(estado_civil[i])
        n_Pacifica_estrato.append(estrato[i])
        n_Pacifica_genero.append(genero[i])
        n_Pacifica_promedio.append(promedio[i])
        n_Pacifica_region.append(region[i])   
        n_Pacifica_llave.append(llave[i])

for i in range(len(region)):
    if region[i] == "Orinoquia" and genero[i] == "masculino":
        m_Orinoquia_edades.append(edades[i])
        m_Orinoquia_escolaridad.append(escolaridad[i])
        m_Orinoquia_estado_civil.append(estado_civil[i])
        m_Orinoquia_estrato.append(estrato[i])
        m_Orinoquia_genero.append(genero[i])
        m_Orinoquia_promedio.append(promedio[i])
        m_Orinoquia_region.append(region[i])   
        m_Orinoquia_llave.append(llave[i])
    elif region[i] == "Orinoquia" and genero[i] == "femenino":
        f_Orinoquia_edades.append(edades[i])
        f_Orinoquia_escolaridad.append(escolaridad[i])
        f_Orinoquia_estado_civil.append(estado_civil[i])
        f_Orinoquia_estrato.append(estrato[i])
        f_Orinoquia_genero.append(genero[i])
        f_Orinoquia_promedio.append(promedio[i])
        f_Orinoquia_region.append(region[i])   
        f_Orinoquia_llave.append(llave[i])
    elif region[i] == "Orinoquia" and genero[i] == "otro":
        o_Orinoquia_edades.append(edades[i])
        o_Orinoquia_escolaridad.append(escolaridad[i])
        o_Orinoquia_estado_civil.append(estado_civil[i])
        o_Orinoquia_estrato.append(estrato[i])
        o_Orinoquia_genero.append(genero[i])
        o_Orinoquia_promedio.append(promedio[i])
        o_Orinoquia_region.append(region[i])   
        o_Orinoquia_llave.append(llave[i])
    elif region[i] == "Orinoquia" and genero[i] == "no binario":
        n_Orinoquia_edades.append(edades[i])
        n_Orinoquia_escolaridad.append(escolaridad[i])
        n_Orinoquia_estado_civil.append(estado_civil[i])
        n_Orinoquia_estrato.append(estrato[i])
        n_Orinoquia_genero.append(genero[i])
        n_Orinoquia_promedio.append(promedio[i])
        n_Orinoquia_region.append(region[i])   
        n_Orinoquia_llave.append(llave[i])
        
        
for i in range(len(region)):
    if region[i] == "Caribe" and genero[i] == "masculino":
        m_Caribe_edades.append(edades[i])
        m_Caribe_escolaridad.append(escolaridad[i])
        m_Caribe_estado_civil.append(estado_civil[i])
        m_Caribe_estrato.append(estrato[i])
        m_Caribe_genero.append(genero[i])
        m_Caribe_promedio.append(promedio[i])
        m_Caribe_region.append(region[i])   
        m_Caribe_llave.append(llave[i])
    elif region[i] == "Caribe" and genero[i] == "femenino":
        f_Caribe_edades.append(edades[i])
        f_Caribe_escolaridad.append(escolaridad[i])
        f_Caribe_estado_civil.append(estado_civil[i])
        f_Caribe_estrato.append(estrato[i])
        f_Caribe_genero.append(genero[i])
        f_Caribe_promedio.append(promedio[i])
        f_Caribe_region.append(region[i])   
        f_Caribe_llave.append(llave[i])
    elif region[i] == "Caribe" and genero[i] == "otro":
        o_Caribe_edades.append(edades[i])
        o_Caribe_escolaridad.append(escolaridad[i])
        o_Caribe_estado_civil.append(estado_civil[i])
        o_Caribe_estrato.append(estrato[i])
        o_Caribe_genero.append(genero[i])
        o_Caribe_promedio.append(promedio[i])
        o_Caribe_region.append(region[i])   
        o_Caribe_llave.append(llave[i])
    elif region[i] == "Caribe" and genero[i] == "no binario":
        n_Caribe_edades.append(edades[i])
        n_Caribe_escolaridad.append(escolaridad[i])
        n_Caribe_estado_civil.append(estado_civil[i])
        n_Caribe_estrato.append(estrato[i])
        n_Caribe_genero.append(genero[i])
        n_Caribe_promedio.append(promedio[i])
        n_Caribe_region.append(region[i])   
        n_Caribe_llave.append(llave[i])
        
for i in range(len(region)):
    if region[i] == "Amazonia" and genero[i] == "masculino":
        m_Amazonia_edades.append(edades[i])
        m_Amazonia_escolaridad.append(escolaridad[i])
        m_Amazonia_estado_civil.append(estado_civil[i])
        m_Amazonia_estrato.append(estrato[i])
        m_Amazonia_genero.append(genero[i])
        m_Amazonia_promedio.append(promedio[i])
        m_Amazonia_region.append(region[i])   
        m_Amazonia_llave.append(llave[i])
    elif region[i] == "Amazonia" and genero[i] == "femenino":
        f_Amazonia_edades.append(edades[i])
        f_Amazonia_escolaridad.append(escolaridad[i])
        f_Amazonia_estado_civil.append(estado_civil[i])
        f_Amazonia_estrato.append(estrato[i])
        f_Amazonia_genero.append(genero[i])
        f_Amazonia_promedio.append(promedio[i])
        f_Amazonia_region.append(region[i])   
        f_Amazonia_llave.append(llave[i])
    elif region[i] == "Amazonia" and genero[i] == "otro":
        o_Amazonia_edades.append(edades[i])
        o_Amazonia_escolaridad.append(escolaridad[i])
        o_Amazonia_estado_civil.append(estado_civil[i])
        o_Amazonia_estrato.append(estrato[i])
        o_Amazonia_genero.append(genero[i])
        o_Amazonia_promedio.append(promedio[i])
        o_Amazonia_region.append(region[i])   
        o_Amazonia_llave.append(llave[i])
    elif region[i] == "Amazonia" and genero[i] == "no binario":
        n_Amazonia_edades.append(edades[i])
        n_Amazonia_escolaridad.append(escolaridad[i])
        n_Amazonia_estado_civil.append(estado_civil[i])
        n_Amazonia_estrato.append(estrato[i])
        n_Amazonia_genero.append(genero[i])
        n_Amazonia_promedio.append(promedio[i])
        n_Amazonia_region.append(region[i])   
        n_Amazonia_llave.append(llave[i])


#unir todos los datos en una lista y ordenarlos por el promedio

mA = list(zip(m_Amazonia_llave,m_Amazonia_edades,m_Amazonia_escolaridad,m_Amazonia_estado_civil,m_Amazonia_estrato,m_Amazonia_genero,m_Amazonia_promedio,m_Amazonia_region))
mA.sort(key = lambda x: x[6], reverse = True)

fA = list(zip(f_Amazonia_llave,f_Amazonia_edades,f_Amazonia_escolaridad,f_Amazonia_estado_civil,f_Amazonia_estrato,f_Amazonia_genero,f_Amazonia_promedio,f_Amazonia_region))
fA.sort(key = lambda x: x[6], reverse = True)

oA = list(zip(o_Amazonia_llave,o_Amazonia_edades,o_Amazonia_escolaridad,o_Amazonia_estado_civil,o_Amazonia_estrato,o_Amazonia_genero,o_Amazonia_promedio,o_Amazonia_region))
oA.sort(key = lambda x: x[6], reverse = True)

nA = list(zip(n_Amazonia_llave,n_Amazonia_edades,n_Amazonia_escolaridad,n_Amazonia_estado_civil,n_Amazonia_estrato,n_Amazonia_genero,n_Amazonia_promedio,n_Amazonia_region))
nA.sort(key = lambda x: x[6], reverse = True)


mC = list(zip(m_Caribe_llave,m_Caribe_edades,m_Caribe_escolaridad,m_Caribe_estado_civil,m_Caribe_estrato,m_Caribe_genero,m_Caribe_promedio,m_Caribe_region))
mC.sort(key = lambda x: x[6], reverse = True)

fC = list(zip(f_Caribe_llave,f_Caribe_edades,f_Caribe_escolaridad,f_Caribe_estado_civil,f_Caribe_estrato,f_Caribe_genero,f_Caribe_promedio,f_Caribe_region))
fC.sort(key = lambda x: x[6], reverse = True)

oC = list(zip(o_Caribe_llave,o_Caribe_edades,o_Caribe_escolaridad,o_Caribe_estado_civil,o_Caribe_estrato,o_Caribe_genero,o_Caribe_promedio,o_Caribe_region))
oC.sort(key = lambda x: x[6], reverse = True)

nC = list(zip(n_Caribe_llave,n_Caribe_edades,n_Caribe_escolaridad,n_Caribe_estado_civil,n_Caribe_estrato,n_Caribe_genero,n_Caribe_promedio,n_Caribe_region))
nC.sort(key = lambda x: x[6], reverse = True)


mP = list(zip(m_Pacifica_llave,m_Pacifica_edades,m_Pacifica_escolaridad,m_Pacifica_estado_civil,m_Pacifica_estrato,m_Pacifica_genero,m_Pacifica_promedio,m_Pacifica_region))
mP.sort(key = lambda x: x[6], reverse = True)

fP = list(zip(f_Pacifica_llave,f_Pacifica_edades,f_Pacifica_escolaridad,f_Pacifica_estado_civil,f_Pacifica_estrato,f_Pacifica_genero,f_Pacifica_promedio,f_Pacifica_region))
fP.sort(key = lambda x: x[6], reverse = True)

oP = list(zip(o_Pacifica_llave,o_Pacifica_edades,o_Pacifica_escolaridad,o_Pacifica_estado_civil,o_Pacifica_estrato,o_Pacifica_genero,o_Pacifica_promedio,o_Pacifica_region))
oP.sort(key = lambda x: x[6], reverse = True)

nP = list(zip(n_Pacifica_llave,n_Pacifica_edades,n_Pacifica_escolaridad,n_Pacifica_estado_civil,n_Pacifica_estrato,n_Pacifica_genero,n_Pacifica_promedio,n_Pacifica_region))
nP.sort(key = lambda x: x[6], reverse = True)


mO = list(zip(m_Orinoquia_llave,m_Orinoquia_edades,m_Orinoquia_escolaridad,m_Orinoquia_estado_civil,m_Orinoquia_estrato,m_Orinoquia_genero,m_Orinoquia_promedio,m_Orinoquia_region))
mO.sort(key = lambda x: x[6], reverse = True)

fO = list(zip(f_Orinoquia_llave,f_Orinoquia_edades,f_Orinoquia_escolaridad,f_Orinoquia_estado_civil,f_Orinoquia_estrato,f_Orinoquia_genero,f_Orinoquia_promedio,f_Orinoquia_region))
fO.sort(key = lambda x: x[6], reverse = True)

oO = list(zip(o_Orinoquia_llave,o_Orinoquia_edades,o_Orinoquia_escolaridad,o_Orinoquia_estado_civil,o_Orinoquia_estrato,o_Orinoquia_genero,o_Orinoquia_promedio,o_Orinoquia_region))
oO.sort(key = lambda x: x[6], reverse = True)

nO = list(zip(n_Orinoquia_llave,n_Orinoquia_edades,n_Orinoquia_escolaridad,n_Orinoquia_estado_civil,n_Orinoquia_estrato,n_Orinoquia_genero,n_Orinoquia_promedio,n_Orinoquia_region))
nO.sort(key = lambda x: x[6], reverse = True)


mAN = list(zip(m_Andina_llave,m_Andina_edades,m_Andina_escolaridad,m_Andina_estado_civil,m_Andina_estrato,m_Andina_genero,m_Andina_promedio,m_Andina_region))
mAN.sort(key = lambda x: x[6], reverse = True)

fAN = list(zip(f_Andina_llave,f_Andina_edades,f_Andina_escolaridad,f_Andina_estado_civil,f_Andina_estrato,f_Andina_genero,f_Andina_promedio,f_Andina_region))
fAN.sort(key = lambda x: x[6], reverse = True)

oAN = list(zip(o_Andina_llave,o_Andina_edades,o_Andina_escolaridad,o_Andina_estado_civil,o_Andina_estrato,o_Andina_genero,o_Andina_promedio,o_Andina_region))
oAN.sort(key = lambda x: x[6], reverse = True)

nAN = list(zip(n_Andina_llave,n_Andina_edades,n_Andina_escolaridad,n_Andina_estado_civil,n_Andina_estrato,n_Andina_genero,n_Andina_promedio,n_Andina_region))
nAN.sort(key = lambda x: x[6], reverse = True)
        
        
        
        
'''print (len(region))
print (len(mO))
print (len(fO))
print (len(oO))
print (len(nO))


print (len(region))
print (len(mA))
print (len(fA))
print (len(oA))
print (len(nA))



print (m_Orinoquia_genero)
print (f_Orinoquia_genero)
print (o_Orinoquia_genero)
print (n_Orinoquia_genero)
'''
# Out:
# [('Andina', 142), ('Pacifica', 117), ('Orinoquia', 33), ('Caribe', 193), ('Amazonia', 15)]
# [('masculino', 204), ('femenino', 251), ('otro', 6), ('no binario', 39)]
# 'print (len(region))\nprint (len(mO))\nprint (len(fO))\nprint (len(oO))\nprint (len(nO))\n\n\nprint (len(region))\nprint (len(mA))\nprint (len(fA))\nprint (len(oA))\nprint (len(nA))\n\n\n\nprint (m_Orinoquia_genero)\nprint (f_Orinoquia_genero)\nprint (o_Orinoquia_genero)\nprint (n_Orinoquia_genero)\n'

# %%
print("Ingrese el número de becas que desea asignar en número")
becas = input ()
becas= int (becas)
b1 = becas


#while becas >= 5:
n=0
becas_region = becas

if (len (mA) + len (fA) + len (oA)+len (nA)) > 0:
        n = n + 1
if (len (mC) + len (fC) + len (oC)+len (nC)) > 0:
        n = n + 1
if (len (mP) + len (fP) + len (oP)+len (nP)) > 0:
        n = n + 1
if (len (mO) + len (fO) + len (oO)+len (nO)) > 0:
        n = n + 1
if (len (mAN) + len (fAN) + len (oAN)+len (nAN)) > 0:
        n = n + 1
x=becas/n

i=0        
if len (mA) > 0:
        i = i + 1
if len (fA) > 0:
        i = i + 1
if len (oA) > 0:
        i = i + 1
if len (nA) > 0:
        i = i + 1

j=0        
if len (mC) > 0:
        j = j + 1
if len (fC) > 0:
        j = j + 1
if len (oC) > 0:
        j = j + 1
if len (nC) > 0:
        j = j + 1

k=0        
if len (mP) > 0:
        k = k + 1
if len (fP) > 0:
        k = k + 1
if len (oP) > 0:
        k = k + 1
if len (nP) > 0:
        k = k + 1


l=0        
if len (mO) > 0:
        l = l + 1
if len (fO) > 0:
        l = l + 1
if len (oO) > 0:
        l = l + 1
if len (nO) > 0:
        l = l + 1        

m=0        
if len (mAN) > 0:
        m = m + 1
if len (fAN) > 0:
        m = m + 1
if len (oAN) > 0:
        m = m + 1
if len (nAN) > 0:
        m = m + 1

while becas_region%n != 0:
    becas_region = becas_region - 1

becas_A = (becas_region/n)
while becas_A%i != 0:
    becas_A = becas_A - 1

becas_C = (becas_region/n)
while becas_C%j != 0:
    becas_C= becas_C - 1

becas_P = (becas_region/n)
while becas_P%k != 0:
    becas_P = becas_P - 1

becas_O = (becas_region/n)
while becas_O%l != 0:
    becas_O = becas_O - 1

becas_AN = (becas_region/n)
while becas_AN%m != 0:
    becas_AN = becas_AN - 1



A_min = 0
if len (mA) <= len (fA) and len(mA) <= len (nA) and len (mA) <= len (oA) and len (mA) != 0 and len (fA)!= 0:
            A_min = len (mA)
elif len (fA)<=len(oA) and len(fA)<=len(nA) and len(fA) != 0 and len(oA)!= 0:
        A_min= len (fA)
elif len(oA)<=len(nA) and len (oA)!= 0 and len (nA) != 0:
    A_min= len (oA)
elif len (nA) != 0:
    A_min= len(nA)
elif len (nA) == 0:
    A_min= len(oA)
    
C_min = 0   
if len (mC) <= len (fC) and len(mC) <= len (nC) and len (mC) <= len (oC) and len (mC) != 0 and len (fC)!= 0:
            C_min = len (mC)
elif len (fC)<=len(oC) and len(fC)<=len(nC) and len(fC) != 0 and len(oC)!= 0:
        C_min= len (fC)
elif len(oC)<=len(nC) and len (oC)!= 0 and len (nC) != 0:
    C_min= len (oC)
elif len (nC) != 0:
    C_min= len(nC)
elif len (nC) == 0:
    C_min= len(oC)
    
P_min = 0   
if len (mP) <= len (fP) and len(mP) <= len (nP) and len (mP) <= len (oP) and len (mP) != 0 and len (fP)!= 0:
            P_min = len (mP)
elif len (fP)<=len(oP) and len(fP)<=len(nP) and len(fP) != 0 and len(oP)!= 0:
        P_min= len (fP)
elif len(oP)<=len(nP) and len (oP)!= 0 and len (nP) != 0:
    P_min= len (oP)
elif len (nP) != 0:
    P_min= len(nP)
elif len (nP) == 0:
    P_min= len(oP)
    
    
O_min = 0   
if len (mO) <= len (fO) and len(mO) <= len (nO) and len (mO) <= len (oO) and len (mO) != 0 and len (fO)!= 0 and len(nO) !=0 and len(oO)!=0:
            O_min = len (mO)
elif len (fO)<=len(oO) and len(fO)<=len(nO) and len(fO) != 0 and len(oO)!= 0 and len (nO) != 0:
        O_min= len (fO)
elif len(oO)<=len(nO) and len (oO)!= 0 and len (nO) != 0:
    O_min= len (oO)
elif len (nO) != 0:
    O_min= len(nO)
elif len (nO) == 0:
    O_min= len(oO)
    
    
AN_min = 0   
if len (mAN) <= len (fAN) and len(mAN) <= len (nAN) and len (mAN) <= len (ANAN) and len (mAN) != 0 and len (fAN)!= 0:
            AN_min = len (mO)
elif len (fAN)<=len(oAN) and len(fAN)<=len(nAN) and len(fAN) != 0 and len(oAN)!= 0:
        AN_min= len (fAN)
elif len(oAN)<=len(nAN) and len (oAN)!= 0 and len (nAN) != 0:
    AN_min= len (oAN)
elif len (nAN) != 0:
    AN_min= len(nAN) 
elif len (nAN) == 0:
    AN_min= len(oAN)


    
if (A_min*i) < (x):
    a1 = int(A_min)
else:
    a1 = int(x/i)
    
if (C_min*j) < (x):
    C1 = int(C_min)
else:
    C1 = int(x/j)
    
if (P_min*k) < (x):
    p1 = int(P_min)
else:
    p1 = int(x/k)
    
if (O_min*l) < (x):
    O1 = int(O_min)
else:
    O1 = int(x/l)
    
if (AN_min*m) < (x):
    AN1 = int(AN_min)
else:
    AN1 = int(x/m)
    
    
becas = becas - ((a1*i)+(C1*j)+(p1*k)+(O1*l)+(AN1*m))


ele_A =[]
ele_A.extend(mA[:a1])
ele_A.extend(fA[:a1])
ele_A.extend(nA[:a1])
ele_A.extend(oA[:a1])

ele_C =[]
ele_C.extend(mC[:C1])
ele_C.extend(fC[:C1])
ele_C.extend(nC[:C1])
ele_C.extend(oC[:C1])

ele_P =[]
ele_P.extend(mP[:p1])
ele_P.extend(fP[:p1])
ele_P.extend(nP[:p1])
ele_P.extend(oP[:p1])

ele_O =[]
ele_O.extend(mO[:O1])
ele_O.extend(fO[:O1])
ele_O.extend(nO[:O1])
ele_O.extend(oO[:O1])

ele_AN =[]
ele_AN.extend(mAN[:AN1])
ele_AN.extend(fAN[:AN1])
ele_AN.extend(nAN[:AN1])
ele_AN.extend(oAN[:AN1])

    
'''print ("min_P",O_min)     
print (i)
print (j)
print (k)
print (l)
print (m)
print (becas_region)
print (becas)
print (becas_A)
print (becas_C)
print (becas_O)
print (becas_P)
print (becas_AN)'''

print("Las becas disponibles se dividen en las",n,"regiones con candidatos, lo que quiere decir que para cada region le corresponden",x,"becas,")
print("sin embargo, para garantizar la igualdad entre los géneros de la región, sólo se puede tomar el género con menos candidatos disponibles")
print("\n por lo cual a la región Amazonía le corresponden",(a1*i),"becas, distribuidas de la siguiente forma:\n")
for f1 in ele_A:
    print(f1)
print("\n por lo cual a la región Caribe le corresponden",(C1*j),"becas, distribuidas de la siguiente forma:\n")
for f2 in ele_C:
    print(f2)
print("\n por lo cual a la región Pacífico le corresponden",(p1*k),"becas, distribuidas de la siguiente forma:\n")
for f3 in ele_P:
    print(f3)
print("\n por lo cual a la región Orinoquía le corresponden",(O1*l),"becas, distribuidas de la siguiente forma:\n")
for f4 in ele_O:
    print(f4)
print("\n por lo cual a la región Andina le corresponden",(AN1*m),"becas, distribuidas de la siguiente forma:\n")
for f5 in ele_AN:
    print(f5)
    
print("\nPara un total de",b1-becas,"distribuidas y un excedente de",becas)

elegidos_region = []
elegidos_region.extend(ele_A)
elegidos_region.extend(ele_C)
elegidos_region.extend(ele_P)
elegidos_region.extend(ele_O)
elegidos_region.extend(ele_AN)
# Out:
# Ingrese el número de becas que desea asignar en número
# 100
# Las becas disponibles se dividen en las 5 regiones con candidatos, lo que quiere decir que para cada region le corresponden 20.0 becas,
# sin embargo, para garantizar la igualdad entre los géneros de la región, sólo se puede tomar el género con menos candidatos disponibles
#
#  por lo cual a la región Amazonía le corresponden 8 becas, distribuidas de la siguiente forma:
#
# (49, 20, 'Secundaria', 'soltera', 3, 'masculino', 4.5, 'Amazonia')
# (488, 39, 'Secundaria', 'soltera', 3, 'masculino', 3.3, 'Amazonia')
# (478, 27, 'Secundaria', 'casada', 2, 'femenino', 4.6, 'Amazonia')
# (220, 43, 'Secundaria', 'divorciada', 4, 'femenino', 2.9, 'Amazonia')
# (375, 21, 'Secundaria', 'casada', 3, 'no binario', 1.5, 'Amazonia')
# (241, 54, 'Secundaria', 'divorciada', 3, 'no binario', 0.5, 'Amazonia')
# (195, 75, 'Secundaria', 'casada', 4, 'otro', 3.1, 'Amazonia')
# (456, 80, 'Secundaria', 'divorciada', 2, 'otro', 3.0, 'Amazonia')
#
# ...

# %% [markdown]
# **Misión 6**
#
# Desarrollar un algoritmo, a partir de lo anterior, cuyo resultado permita al comité comparar fácilmente las características de las dos poblaciones hipotéticas que recibirían becas.
#
# *Ayuda*: considera utilizar tus implementaciones de la *Misión 2* para facilitar esta misión.

# %%
numero_de_grupos = 1
indice_barras = np.arange(numero_de_grupos)
ancho_barras =0.35
 
plt.bar(indice_barras, len(elegidos), width=ancho_barras, label='Estrato')
plt.bar(indice_barras + ancho_barras, len(elegidos_region), width=ancho_barras, label='Regiones')
plt.legend(loc='best')
plt.xticks(indice_barras + ancho_barras, (''))
 
plt.ylabel('Cantidad de personas')
plt.xlabel('Opciones')
plt.title('Numero de personas por opción')
 
plt.show()

# %% [markdown]
# ## 3. Desarrollo de una solución analítica
#
# Reconociendo la complejidad de este problema (que no permite reducirlo a una dicotomía) y viendo el potencial del análisis de datos para enriquecer la discusión y los insumos para tomar decisiones, el comité ha solicitado una herramienta analítica que les permita . Sus requerimientos son:
#
# * La herramienta debe permitir ingresar una política de selección de becados.
#     * Se debe poder elegir el rango de edad de los aspirantes.
#     * Se debe poder elegir qué proporción de las becas se asigna a cada género, a cada estrato, o a cada región (pero sólo debe elegirse uno de estos criterios).
# * La herramienta debe generar un resultado que permita al comité analizar las características de la población potencialmente elegida si se usara la política ingresada.
#
# **Misión 7**
#
# Desarrollar, a partir de lo construido hasta el momento, un algoritmo que permita cumplir con los requerimientos del comité.

# %%
import math

#enumerar la lista

list(enumerate (edades))
list(enumerate (escolaridad))
list(enumerate (estado_civil))
list(enumerate (estrato))
list(enumerate (genero))
list(enumerate (promedio))
list(enumerate (region))
llave = range(0,500)

#conocer el grupo de elementos de la lista estrato

from collections import OrderedDict  
  
def group_list(x): 
    res =  [(el, x.count(el)) for el in x ] 
    return list(OrderedDict(res).items()) 

print(group_list(estrato))
# Out:
# [(5, 13), (1, 111), (3, 156), (2, 185), (4, 35)]

# %%
# e5_edades=[]
e5_escolaridad=[]
e5_estado_civil=[]
e5_estrato=[]
e5_genero=[]
e5_promedio=[]
e5_region=[]
e5_llave =[]

e4_edades=[]
e4_escolaridad=[]
e4_estado_civil=[]
e4_estrato=[]
e4_genero=[]
e4_promedio=[]
e4_region=[]
e4_llave =[]

e3_edades=[]
e3_escolaridad=[]
e3_estado_civil=[]
e3_estrato=[]
e3_genero=[]
e3_promedio=[]
e3_region=[]
e3_llave =[]

e2_edades=[]
e2_escolaridad=[]
e2_estado_civil=[]
e2_estrato=[]
e2_genero=[]
e2_promedio=[]
e2_region=[]
e2_llave =[]

e1_edades=[]
e1_escolaridad=[]
e1_estado_civil=[]
e1_estrato=[]
e1_genero=[]
e1_promedio=[]
e1_region=[]
e1_llave =[]



por_e1 = 0
por_e2 = 0
por_e3 = 0
por_e4 = 0
por_e5 = 0



print("Ingrese el número de becas que desea asignar en número")
becas = input ()
becas= int (becas)

print("Ingrese la edad mínima en número")
xmin = input ()
xmin= int (xmin)

print("Ingrese la edad máxima en número")
xmax = input ()
xmax= int (xmax)

print("Ingrese el número de la opción que desea: \n1. Estrato\n2. Región \n3. Género")
opcion = input ()
opcion= int (opcion)

if opcion == 1:

    print("Ingrese el porcentaje de 0 a 100 que desea asignar al estrato 1 ")
    por_e1 = float(input ())
    por_e1= float (por_e1/100)
    if (por_e1*100) < 100:
        print("Ingrese el porcentaje de 0 a",100-(por_e1*100),"que desea asignar al estrato 2 ")
        por_e2 = float(input ())
        por_e2= float (por_e2/100)
        if (por_e2*100) < (100-(por_e1*100)):
                print("Ingrese el porcentaje de 0 a",100-(por_e1*100)-(por_e2*100),"que desea asignar al estrato 3 ")
                por_e3 = float(input ())
                por_e3= float (por_e3/100)
                if (por_e3*100) < (100-(por_e1*100)-(por_e2*100)):
                    print("Ingrese el porcentaje de 0 a",100-(por_e1*100)-(por_e2*100)-(por_e3*100),"que desea asignar al estrato 4 ")
                    por_e4 = float(input ())
                    por_e4= float (por_e4/100)
                    por_e5= float (100-(por_e1*100)-(por_e2*100)-(por_e3*100)-(por_e4*100))
                    por_e5= float (por_e5/100)
                    print("Su asignación fue:\nEstrato 1:",por_e1*100,"\nEstrato 2",por_e2*100,"\nEstrato 3",por_e3*100,"\nEstrato 4",por_e4*100,"\nEstrato 5",por_e5*100)
                else:
                    print("Su asignación fue:\nEstrato 1:",por_e1*100,"\nEstrato 2",por_e2*100,"\nEstrato 3",por_e3*100,"\nEstrato 4",por_e4*100)
        else:
                print("Su asignación fue:\nEstrato 1:",por_e1*100,"\nEstrato 2",por_e2*100,"\nEstrato 3",por_e3*100)
    else:
        print("Su asignación fue:\nEstrato 1:",por_e1*100,"\nEstrato 2",por_e2*100)



    #Separa a las personas por estratos y el rango de edades
    for i in range(len(estrato)):
        if estrato[i] == 5 and edades[i] <= xmax and edades[i] >= xmin:
            e5_edades.append(edades[i])
            e5_escolaridad.append(escolaridad[i])
            e5_estado_civil.append(estado_civil[i])
            e5_estrato.append(estrato[i])
            e5_genero.append(genero[i])
            e5_promedio.append(promedio[i])
            e5_region.append(region[i])
            e5_llave.append(llave[i])

    for i in range(len(estrato)):
        if estrato[i] == 4 and edades[i] <= xmax and edades[i] >= xmin:
            e4_edades.append(edades[i])
            e4_escolaridad.append(escolaridad[i])
            e4_estado_civil.append(estado_civil[i])
            e4_estrato.append(estrato[i])
            e4_genero.append(genero[i])
            e4_promedio.append(promedio[i])
            e4_region.append(region[i])
            e4_llave.append(llave[i])

    for i in range(len(estrato)):
        if estrato[i] == 3 and edades[i] <= xmax and edades[i] >= xmin:
            e3_edades.append(edades[i])
            e3_escolaridad.append(escolaridad[i])
            e3_estado_civil.append(estado_civil[i])
            e3_estrato.append(estrato[i])
            e3_genero.append(genero[i])
            e3_promedio.append(promedio[i])
            e3_region.append(region[i])
            e3_llave.append(llave[i])   


    for i in range(len(estrato)):
        if estrato[i] == 2 and edades[i] <= xmax and edades[i] >= xmin:
            e2_edades.append(edades[i])
            e2_escolaridad.append(escolaridad[i])
            e2_estado_civil.append(estado_civil[i])
            e2_estrato.append(estrato[i])
            e2_genero.append(genero[i])
            e2_promedio.append(promedio[i])
            e2_region.append(region[i])   
            e2_llave.append(llave[i])

    for i in range(len(estrato)):
        if estrato[i] == 1 and edades[i] <= xmax and edades[i] >= xmin:
            e1_edades.append(edades[i])
            e1_escolaridad.append(escolaridad[i])
            e1_estado_civil.append(estado_civil[i])
            e1_estrato.append(estrato[i])
            e1_genero.append(genero[i])
            e1_promedio.append(promedio[i])
            e1_region.append(region[i])   
            e1_llave.append(llave[i])

    #unir todos los datos en una lista y ordenarlos por el promedio

    e5 = list(zip(e5_llave,e5_edades,e5_escolaridad,e5_estado_civil,e5_estrato,e5_genero,e5_promedio,e5_region))
    e5.sort(key = lambda x: x[6], reverse = True)

    e4 = list(zip(e4_llave,e4_edades,e4_escolaridad,e4_estado_civil,e4_estrato,e4_genero,e4_promedio,e4_region))
    e4.sort(key = lambda x: x[6], reverse = True)

    e3 = list(zip(e3_llave,e3_edades,e3_escolaridad,e3_estado_civil,e3_estrato,e3_genero,e3_promedio,e3_region))
    e3.sort(key = lambda x: x[6], reverse = True)

    e2 = list(zip(e2_llave,e2_edades,e2_escolaridad,e2_estado_civil,e2_estrato,e2_genero,e2_promedio,e2_region))
    e2.sort(key = lambda x: x[6], reverse = True)

    e1 = list(zip(e1_llave,e1_edades,e1_escolaridad,e1_estado_civil,e1_estrato,e1_genero,e1_promedio,e1_region))
    e1.sort(key = lambda x: x[6], reverse = True)


    elegidos = []
    xbecas = becas
    if becas*por_e1 < len(e1):
        elegidos.extend(e1[:(math.ceil(becas*por_e1))])
        xbecas = xbecas - (math.ceil(becas*por_e1))
    else:
        elegidos.extend(e1[:len(e1)])
        xbecas = xbecas - len(e1)

    if becas*por_e2 < len(e2):
        elegidos.extend(e2[:(math.ceil(becas*por_e2))])
        xbecas = xbecas - (math.ceil(becas*por_e2))
    else:
        elegidos.extend(e2[:len(e2)])
        xbecas = xbecas - len(e2)

    if becas*por_e3 < len(e3):
        elegidos.extend(e3[:(math.ceil(becas*por_e3))])
        xbecas = xbecas - (math.ceil(becas*por_e3))
    else:
        elegidos.extend(e3[:len(e3)])
        xbecas = xbecas - len(e3)

    if becas*por_e4 < len(e4):
        elegidos.extend(e4[:(math.ceil(becas*por_e4))])
        xbecas = xbecas - (math.ceil(becas*por_e4))
    else:
        elegidos.extend(e4[:len(e4)])
        xbecas = xbecas - len(e4)

    if becas*por_e5 < len(e5):
        elgidos.extend(e5[:(math.ceil(becas*por_e5))])
        xbecas = xbecas - (math.ceil(becas*por_e5))
    else:
        elegidos.extend(e5[:len(e5)])
        xbecas = xbecas - len(e5)



    print("\npara el rango de edad entre",xmin,"años y",xmax,"años fueron asignadas",len(elegidos),"becas de las",becas,"disponibles y quedaron",xbecas,"sin asignar")
    print("\nlas personas elegidas fueron:")
    for i in elegidos:
        print (i)

        
elif opcion == 2:
    
    print("Ingrese el porcentaje de 0 a 100 que desea asignar a la región Andina ")
    por_e1 = float(input ())
    por_e1= float (por_e1/100)
    if (por_e1*100) < 100:
        print("Ingrese el porcentaje de 0 a",100-(por_e1*100),"que desea asignar a la región Caribe ")
        por_e2 = float(input ())
        por_e2= float (por_e2/100)
        if (por_e2*100) < (100-(por_e1*100)):
                print("Ingrese el porcentaje de 0 a",100-(por_e1*100)-(por_e2*100),"que desea asignar a la región Pacifica ")
                por_e3 = float(input ())
                por_e3= float (por_e3/100)
                if (por_e3*100) < (100-(por_e1*100)-(por_e2*100)):
                    print("Ingrese el porcentaje de 0 a",100-(por_e1*100)-(por_e2*100)-(por_e3*100),"que desea asignar a la región Orinoquia ")
                    por_e4 = float(input ())
                    por_e4= float (por_e4/100)
                    por_e5= float (100-(por_e1*100)-(por_e2*100)-(por_e3*100)-(por_e4*100))
                    por_e5= float (por_e5/100)
                    print("Su asignación fue:\nAndina :",por_e1*100,"\nCaribe ",por_e2*100,"\nPacifica",por_e3*100,"\nOrinoquía",por_e4*100,"\nAmazonía",por_e5*100)
                else:
                    print("Su asignación fue:\nAndina 1:",por_e1*100,"\nCaribe 2",por_e2*100,"\nPacifica 3",por_e3*100,"\nOrinoquía 4",por_e4*100)
        else:
                print("Su asignación fue:\nAndina 1:",por_e1*100,"\nCaribe 2",por_e2*100,"\nPacifica 3",por_e3*100)
    else:
        print("Su asignación fue:\nAndina 1:",por_e1*100,"\nCaribe 2",por_e2*100)



    #Separa a las personas por estratos y el rango de edades
    for i in range(len(region)):
        if region[i] == "Amazonia" and edades[i] <= xmax and edades[i] >= xmin:
            e5_edades.append(edades[i])
            e5_escolaridad.append(escolaridad[i])
            e5_estado_civil.append(estado_civil[i])
            e5_estrato.append(estrato[i])
            e5_genero.append(genero[i])
            e5_promedio.append(promedio[i])
            e5_region.append(region[i])
            e5_llave.append(llave[i])

    for i in range(len(region)):
        if region[i] == "Orinoquia" and edades[i] <= xmax and edades[i] >= xmin:
            e4_edades.append(edades[i])
            e4_escolaridad.append(escolaridad[i])
            e4_estado_civil.append(estado_civil[i])
            e4_estrato.append(estrato[i])
            e4_genero.append(genero[i])
            e4_promedio.append(promedio[i])
            e4_region.append(region[i])
            e4_llave.append(llave[i])

    for i in range(len(region)):
        if region[i] == "Pacifica" and edades[i] <= xmax and edades[i] >= xmin:
            e3_edades.append(edades[i])
            e3_escolaridad.append(escolaridad[i])
            e3_estado_civil.append(estado_civil[i])
            e3_estrato.append(estrato[i])
            e3_genero.append(genero[i])
            e3_promedio.append(promedio[i])
            e3_region.append(region[i])
            e3_llave.append(llave[i])   


    for i in range(len(region)):
        if region[i] == "Caribe" and edades[i] <= xmax and edades[i] >= xmin:
            e2_edades.append(edades[i])
            e2_escolaridad.append(escolaridad[i])
            e2_estado_civil.append(estado_civil[i])
            e2_estrato.append(estrato[i])
            e2_genero.append(genero[i])
            e2_promedio.append(promedio[i])
            e2_region.append(region[i])   
            e2_llave.append(llave[i])

    for i in range(len(region)):
        if region[i] == "Andina" and edades[i] <= xmax and edades[i] >= xmin:
            e1_edades.append(edades[i])
            e1_escolaridad.append(escolaridad[i])
            e1_estado_civil.append(estado_civil[i])
            e1_estrato.append(estrato[i])
            e1_genero.append(genero[i])
            e1_promedio.append(promedio[i])
            e1_region.append(region[i])   
            e1_llave.append(llave[i])

    #unir todos los datos en una lista y ordenarlos por el promedio

    e5 = list(zip(e5_llave,e5_edades,e5_escolaridad,e5_estado_civil,e5_estrato,e5_genero,e5_promedio,e5_region))
    e5.sort(key = lambda x: x[6], reverse = True)

    e4 = list(zip(e4_llave,e4_edades,e4_escolaridad,e4_estado_civil,e4_estrato,e4_genero,e4_promedio,e4_region))
    e4.sort(key = lambda x: x[6], reverse = True)

    e3 = list(zip(e3_llave,e3_edades,e3_escolaridad,e3_estado_civil,e3_estrato,e3_genero,e3_promedio,e3_region))
    e3.sort(key = lambda x: x[6], reverse = True)

    e2 = list(zip(e2_llave,e2_edades,e2_escolaridad,e2_estado_civil,e2_estrato,e2_genero,e2_promedio,e2_region))
    e2.sort(key = lambda x: x[6], reverse = True)

    e1 = list(zip(e1_llave,e1_edades,e1_escolaridad,e1_estado_civil,e1_estrato,e1_genero,e1_promedio,e1_region))
    e1.sort(key = lambda x: x[6], reverse = True)


    elegidos = []
    xbecas = becas
    if becas*por_e1 < len(e1):
        elegidos.extend(e1[:(math.ceil(becas*por_e1))])
        xbecas = xbecas - (math.ceil(becas*por_e1))
    else:
        elegidos.extend(e1[:len(e1)])
        xbecas = xbecas - len(e1)

    if becas*por_e2 < len(e2):
        elegidos.extend(e2[:(math.ceil(becas*por_e2))])
        xbecas = xbecas - (math.ceil(becas*por_e2))
    else:
        elegidos.extend(e2[:len(e2)])
        xbecas = xbecas - len(e2)

    if becas*por_e3 < len(e3):
        elegidos.extend(e3[:(math.ceil(becas*por_e3))])
        xbecas = xbecas - (math.ceil(becas*por_e3))
    else:
        elegidos.extend(e3[:len(e3)])
        xbecas = xbecas - len(e3)

    if becas*por_e4 < len(e4):
        elegidos.extend(e4[:(math.ceil(becas*por_e4))])
        xbecas = xbecas - (math.ceil(becas*por_e4))
    else:
        elegidos.extend(e4[:len(e4)])
        xbecas = xbecas - len(e4)

    if becas*por_e5 < len(e5):
        elgidos.extend(e5[:(math.ceil(becas*por_e5))])
        xbecas = xbecas - (math.ceil(becas*por_e5))
    else:
        elegidos.extend(e5[:len(e5)])
        xbecas = xbecas - len(e5)



    print("\npara el rango de edad entre",xmin,"años y",xmax,"años fueron asignadas",len(elegidos),"becas de las",becas,"disponibles y quedaron",xbecas,"sin asignar")
    print("\nlas personas elegidas fueron:")
    for i in elegidos:
        print (i)
        
elif opcion == 3:
    
    print("Ingrese el porcentaje de 0 a 100 que desea asignar al género masculino ")
    por_e1 = float(input ())
    por_e1= float (por_e1/100)
    if (por_e1*100) < 100:
        print("Ingrese el porcentaje de 0 a",100-(por_e1*100),"que desea asignar al género femenino ")
        por_e2 = float(input ())
        por_e2= float (por_e2/100)
        if (por_e2*100) < (100-(por_e1*100)):
                print("Ingrese el porcentaje de 0 a",100-(por_e1*100)-(por_e2*100),"que desea asignar al género otro ")
                por_e3 = float(input ())
                por_e3= float (por_e3/100)
                por_e4= float (100-(por_e1*100)-(por_e2*100)-(por_e3*100))
                por_e4= float (por_e4/100)
                print("Su asignación fue:\nMasculino :",por_e1*100,"\nFemenino ",por_e2*100,"\nOtro",por_e3*100,"\nNo binario",por_e4*100)
        else:
                print("Su asignación fue:\nMasculino :",por_e1*100,"\nFemenino ",por_e2*100,"\nOtro ",por_e3*100)
    else:
        print("Su asignación fue:\nMasculino :",por_e1*100,"\nFemenino ",por_e2*100)



    #Separa a las personas por estratos y el rango de edades


    for i in range(len(genero)):
        if genero[i] == "no binario" and edades[i] <= xmax and edades[i] >= xmin:
            e4_edades.append(edades[i])
            e4_escolaridad.append(escolaridad[i])
            e4_estado_civil.append(estado_civil[i])
            e4_estrato.append(estrato[i])
            e4_genero.append(genero[i])
            e4_promedio.append(promedio[i])
            e4_region.append(region[i])
            e4_llave.append(llave[i])

    for i in range(len(genero)):
        if genero[i] == "otro" and edades[i] <= xmax and edades[i] >= xmin:
            e3_edades.append(edades[i])
            e3_escolaridad.append(escolaridad[i])
            e3_estado_civil.append(estado_civil[i])
            e3_estrato.append(estrato[i])
            e3_genero.append(genero[i])
            e3_promedio.append(promedio[i])
            e3_region.append(region[i])
            e3_llave.append(llave[i])   


    for i in range(len(genero)):
        if genero[i] == "femenino" and edades[i] <= xmax and edades[i] >= xmin:
            e2_edades.append(edades[i])
            e2_escolaridad.append(escolaridad[i])
            e2_estado_civil.append(estado_civil[i])
            e2_estrato.append(estrato[i])
            e2_genero.append(genero[i])
            e2_promedio.append(promedio[i])
            e2_region.append(region[i])   
            e2_llave.append(llave[i])

    for i in range(len(genero)):
        if genero[i] == "masculino" and edades[i] <= xmax and edades[i] >= xmin:
            e1_edades.append(edades[i])
            e1_escolaridad.append(escolaridad[i])
            e1_estado_civil.append(estado_civil[i])
            e1_estrato.append(estrato[i])
            e1_genero.append(genero[i])
            e1_promedio.append(promedio[i])
            e1_region.append(region[i])   
            e1_llave.append(llave[i])

    #unir todos los datos en una lista y ordenarlos por el promedio

    e4 = list(zip(e4_llave,e4_edades,e4_escolaridad,e4_estado_civil,e4_estrato,e4_genero,e4_promedio,e4_region))
    e4.sort(key = lambda x: x[6], reverse = True)

    e3 = list(zip(e3_llave,e3_edades,e3_escolaridad,e3_estado_civil,e3_estrato,e3_genero,e3_promedio,e3_region))
    e3.sort(key = lambda x: x[6], reverse = True)

    e2 = list(zip(e2_llave,e2_edades,e2_escolaridad,e2_estado_civil,e2_estrato,e2_genero,e2_promedio,e2_region))
    e2.sort(key = lambda x: x[6], reverse = True)

    e1 = list(zip(e1_llave,e1_edades,e1_escolaridad,e1_estado_civil,e1_estrato,e1_genero,e1_promedio,e1_region))
    e1.sort(key = lambda x: x[6], reverse = True)


    elegidos = []
    xbecas = becas
    if becas*por_e1 < len(e1):
        elegidos.extend(e1[:(math.ceil(becas*por_e1))])
        xbecas = xbecas - (math.ceil(becas*por_e1))
    else:
        elegidos.extend(e1[:len(e1)])
        xbecas = xbecas - len(e1)

    if becas*por_e2 < len(e2):
        elegidos.extend(e2[:(math.ceil(becas*por_e2))])
        xbecas = xbecas - (math.ceil(becas*por_e2))
    else:
        elegidos.extend(e2[:len(e2)])
        xbecas = xbecas - len(e2)

    if becas*por_e3 < len(e3):
        elegidos.extend(e3[:(math.ceil(becas*por_e3))])
        xbecas = xbecas - (math.ceil(becas*por_e3))
    else:
        elegidos.extend(e3[:len(e3)])
        xbecas = xbecas - len(e3)

    if becas*por_e4 < len(e4):
        elegidos.extend(e4[:(math.ceil(becas*por_e4))])
        xbecas = xbecas - (math.ceil(becas*por_e4))
    else:
        elegidos.extend(e4[:len(e4)])
        xbecas = xbecas - len(e4)


    print("\npara el rango de edad entre",xmin,"años y",xmax,"años fueron asignadas",len(elegidos),"becas de las",becas,"disponibles y quedaron",xbecas,"sin asignar")
    print("\nlas personas elegidas fueron:")
    for i in elegidos:
        print (i)
# Out:
# Ingrese el número de becas que desea asignar en número
# 100
# Ingrese la edad mínima en número
# 2
# Ingrese la edad máxima en número
# 100
# Ingrese el número de la opción que desea:
# 1. Estrato
# 2. Región
# 3. Género
# 1
# Ingrese el porcentaje de 0 a 100 que desea asignar al estrato 1
# 0
# Ingrese el porcentaje de 0 a 100.0 que desea asignar al estrato 2
# 0
# Ingrese el porcentaje de 0 a 100.0 que desea asignar al estrato 3
# 0
# Ingrese el porcentaje de 0 a 100.0 que desea asignar al estrato 4
# 0
# Su asignación fue:
# Estrato 1: 0.0
# Estrato 2 0.0
# Estrato 3 0.0
# Estrato 4 0.0
# Estrato 5 100.0
#
# para el rango de edad entre 2 años y 100 años fueron asignadas 13 becas de las 100 disponibles y quedaron 87 sin asignar
#
# las personas elegidas fueron:
# (259, 60, 'Secundaria', 'soltera', 5, 'no binario', 4.8, 'Andina')
# (99, 64, 'Secundaria', 'viuda', 5, 'femenino', 3.4, 'Orinoquia')
# (38, 47, 'Secundaria', 'casada', 5, 'femenino', 3.3, 'Caribe')
# ...

# %% [markdown]
# **Misión 8**
#
# Proponer, con base en tu propio uso de la herramienta, una política de ingreso que consideres apropiada dado el contexto proporcionado. Si lo crees adecuado, explica, máximo 500 caracteres, las virtudes de tu propuesta (esto puede estar soportado en los datos, o no).

# %%
respuesta = 'Mi propuesta de heramienta es seleccónar los promedios por arriba de 3,5; dividir a las personas por estrato \n y empezar a asignar becas a los estratos más bajos hasta acabar el grupo y después pasar al siguiente '

# %% [markdown]
# **Misión 9**
#
# Ejecutar el algoritmo desarrollado en la *Misión 7* sobre la política que sugieres proponer al comité. Explicar claramente tus conlusiones con el soporte de los resultados de la herramienta.

# %%
#enumerar la lista

list(enumerate (edades))
list(enumerate (escolaridad))
list(enumerate (estado_civil))
list(enumerate (estrato))
list(enumerate (genero))
list(enumerate (promedio))
list(enumerate (region))
llave = range(0,500)

# e5_edades=[]
e5_escolaridad=[]
e5_estado_civil=[]
e5_estrato=[]
e5_genero=[]
e5_promedio=[]
e5_region=[]
e5_llave =[]

e4_edades=[]
e4_escolaridad=[]
e4_estado_civil=[]
e4_estrato=[]
e4_genero=[]
e4_promedio=[]
e4_region=[]
e4_llave =[]

e3_edades=[]
e3_escolaridad=[]
e3_estado_civil=[]
e3_estrato=[]
e3_genero=[]
e3_promedio=[]
e3_region=[]
e3_llave =[]

e2_edades=[]
e2_escolaridad=[]
e2_estado_civil=[]
e2_estrato=[]
e2_genero=[]
e2_promedio=[]
e2_region=[]
e2_llave =[]

e1_edades=[]
e1_escolaridad=[]
e1_estado_civil=[]
e1_estrato=[]
e1_genero=[]
e1_promedio=[]
e1_region=[]
e1_llave =[]

#Separa a las personas por estratos
for i in range(len(estrato)):
    if estrato[i] == 5 and promedio[i]>3.5:
        e5_edades.append(edades[i])
        e5_escolaridad.append(escolaridad[i])
        e5_estado_civil.append(estado_civil[i])
        e5_estrato.append(estrato[i])
        e5_genero.append(genero[i])
        e5_promedio.append(promedio[i])
        e5_region.append(region[i])
        e5_llave.append(llave[i])
        
for i in range(len(estrato)):
    if estrato[i] == 4 and promedio[i]>3.5:
        e4_edades.append(edades[i])
        e4_escolaridad.append(escolaridad[i])
        e4_estado_civil.append(estado_civil[i])
        e4_estrato.append(estrato[i])
        e4_genero.append(genero[i])
        e4_promedio.append(promedio[i])
        e4_region.append(region[i])
        e4_llave.append(llave[i])

for i in range(len(estrato)):
    if estrato[i] == 3 and promedio[i]>3.5:
        e3_edades.append(edades[i])
        e3_escolaridad.append(escolaridad[i])
        e3_estado_civil.append(estado_civil[i])
        e3_estrato.append(estrato[i])
        e3_genero.append(genero[i])
        e3_promedio.append(promedio[i])
        e3_region.append(region[i])
        e3_llave.append(llave[i])   
        
        
for i in range(len(estrato)):
    if estrato[i] == 2 and promedio[i]>3.5:
        e2_edades.append(edades[i])
        e2_escolaridad.append(escolaridad[i])
        e2_estado_civil.append(estado_civil[i])
        e2_estrato.append(estrato[i])
        e2_genero.append(genero[i])
        e2_promedio.append(promedio[i])
        e2_region.append(region[i])   
        e2_llave.append(llave[i])
        
for i in range(len(estrato)):
    if estrato[i] == 1 and promedio[i]>3.5:
        e1_edades.append(edades[i])
        e1_escolaridad.append(escolaridad[i])
        e1_estado_civil.append(estado_civil[i])
        e1_estrato.append(estrato[i])
        e1_genero.append(genero[i])
        e1_promedio.append(promedio[i])
        e1_region.append(region[i])   
        e1_llave.append(llave[i])

#unir todos los datos en una lista y ordenarlos por el promedio

e5 = list(zip(e5_llave,e5_edades,e5_escolaridad,e5_estado_civil,e5_estrato,e5_genero,e5_promedio,e5_region))
e5.sort(key = lambda x: x[6], reverse = True)

e4 = list(zip(e4_llave,e4_edades,e4_escolaridad,e4_estado_civil,e4_estrato,e4_genero,e4_promedio,e4_region))
e4.sort(key = lambda x: x[6], reverse = True)

e3 = list(zip(e3_llave,e3_edades,e3_escolaridad,e3_estado_civil,e3_estrato,e3_genero,e3_promedio,e3_region))
e3.sort(key = lambda x: x[6], reverse = True)

e2 = list(zip(e2_llave,e2_edades,e2_escolaridad,e2_estado_civil,e2_estrato,e2_genero,e2_promedio,e2_region))
e2.sort(key = lambda x: x[6], reverse = True)

e1 = list(zip(e1_llave,e1_edades,e1_escolaridad,e1_estado_civil,e1_estrato,e1_genero,e1_promedio,e1_region))
e1.sort(key = lambda x: x[6], reverse = True)


becas = 100
xbecas = becas
elegidos =[]
if xbecas > len(e1):
    elegidos.extend(e1)
    xbecas= xbecas - len(e1)
    if xbecas > len(e2):
        elegidos.extend(e2)
        xbecas= xbecas - len(e2)
        if xbecas > len(e3):
            elegidos.extend(e3)
            xbecas= xbecas - len(e3)
            if xbecas > len(e4):
                elegidos.extend(e4)
                xbecas= xbecas - len(e4)
                if xbecas > len(e5):
                    elegidos.extend(e5)
                    xbecas= xbecas - len(e5)
                else:
                    elegidos.extend(e5[:xbecas])
                    xbecas = 0
            else:
                    elegidos.extend(e4[:xbecas])
                    xbecas = 0
        else:
                    elegidos.extend(e3[:xbecas])
                    xbecas = 0
    else:
                    elegidos.extend(e2[:xbecas])
                    xbecas = 0
else:
                    elegidos.extend(e1[:xbecas])
                    xbecas = 0

    
    
print("para las",becas,"se asignaron",len(elegidos),"y quedaron por asignar",len(elegidos)-becas,"\n")
for i in elegidos:
    print(i)

conclusion = ''
# Out:
# para las 100 se asignaron 100 y quedaron por asignar 0
#
# (376, 69, 'Secundaria', 'soltera', 1, 'masculino', 5.0, 'Pacifica')
# (162, 47, 'Secundaria', 'casada', 1, 'masculino', 4.9, 'Andina')
# (363, 32, 'Secundaria', 'casada', 1, 'femenino', 4.9, 'Pacifica')
# (283, 28, 'Secundaria', 'divorciada', 1, 'no binario', 4.8, 'Andina')
# (385, 49, 'Secundaria', 'soltera', 1, 'masculino', 4.7, 'Pacifica')
# (287, 20, 'Secundaria', 'soltera', 1, 'femenino', 4.3, 'Pacifica')
# (398, 52, 'Secundaria', 'casada', 1, 'masculino', 4.3, 'Andina')
# (422, 50, 'Secundaria', 'soltera', 1, 'masculino', 4.2, 'Orinoquia')
# (108, 62, 'Profesional', 'viuda', 1, 'femenino', 4.1, 'Caribe')
# (213, 30, 'Secundaria', 'divorciada', 1, 'femenino', 4.1, 'Caribe')
# (250, 25, 'Secundaria', 'divorciada', 1, 'femenino', 4.0, 'Pacifica')
# (253, 57, 'Secundaria', 'soltera', 1, 'masculino', 4.0, 'Pacifica')
# (281, 53, 'Secundaria', 'casada', 1, 'masculino', 4.0, 'Andina')
# ...

# %% [markdown]
# ## Referencias
# * Discriminación Positiva<br>
# https://es.wikipedia.org/wiki/Discriminaci%C3%B3n_positiva
# * Análisis de formulación del programa “Ser Pilo Paga”<br>
# https://repository.urosario.edu.co/handle/10336/12526
# * La acción afirmativa en la Universidad de los Andes: El caso del programa "Oportunidades para talentos nacionales"<br> http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0123-885X2004000300005
# * Acción afirmativa y equidad: un análisis desde la propuesta de Thomas Nagel<br>
# http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2007-24062016000200049

# %% [markdown]
# ## Créditos

# %% [markdown]
# Camilo Gómez - 11/06/21<br>
# *Revisado*: 25/08/21
